# %% [markdown]
# ## Agriculture CDC Data 2019
# Data source: https://data.world/cdc2019/agriculture

# %% [markdown]
# ### Imports and Initialization

# %%
import pandas as pd

# %% [markdown]
# ### Functions

# %%
# print all rows
def display_all(df):
    pd.set_option('display.max_rows', None)
    print(df)
    pd.reset_option('display.max_rows')

# %%
# Given commodity return specific attributes related to the commodity
def get_attributes(commodity):
    return pd.DataFrame(columns = df_main[df_main['Commodity'] == commodity]['Attribute'].unique())

# %%
# Given attribute name, index and 2 dataframe will find value based on attribute
def get_cell (attribute, index, df_main, df_transpose):
        
        # iterate main data frame to look for values based on the attribute
        for index_main in range(0, len(df_main)):
                
            condition = ((df_main.loc[index_main, 'Attribute'] == attribute) & 
                         (df_main.loc[index_main, 'Commodity'] == df_transpose.loc[index, 'Commodity']) & 
                         (df_main.loc[index_main, 'Year'] == df_transpose.loc[index, 'Year'])) 

            if (condition):
                return [df_main.loc[index_main,'Value'] , df_main.loc[index_main,'Units']]
            else:
                continue
        return (-1)

# %%
# Transpose the main data frame for more manageable analysis
def tranpose_table (df_main, df_agriculture, df_units):
    
    # Get first commodity and attributes
    prev_commodity = df_agriculture.iloc[0]['Commodity']
    attributes = get_attributes(prev_commodity)
    
    for index in range(0, len(df_agriculture)):

        # only get new attributes if this is a different commodity from previous iteration
        cur_commodity = df_agriculture.iloc[index]['Commodity']

        if (prev_commodity != cur_commodity):
            prev_commodity = cur_commodity
            attributes = get_attributes(prev_commodity)

        # Iterate all attributes
        for attribute in attributes:

            # replace value of attribute with values from main data frame
            cells = get_cell(attribute, index, df_main, df_agriculture)

            if ((cells[0] != (-1)) & (cells[1] != (-1))):
                df_agriculture.loc[index, attribute] = cells[0]
                df_units.loc[index, attribute] = cells[1]         
    
    # # Fill Nan with zero values
    # df_agriculture.fillna(0, inplace = True)
    # df_units.fillna(0, inplace = True)
    
    return (0)

# %%
# Save data frame in to csv
def save_data_frame_to_csv(df, title):
    df.to_csv(title)

# %% [markdown]
# ### Load CSV File into DataFrame

# %%
# main table from CSV file
df_main = pd.DataFrame(pd.read_csv('dataset/Projection2019.csv'))
df_main.reset_index()
# Out:
#       index             Attribute Commodity CommodityType             Units  \
# 0         0      Beginning stocks    Barley         Crops   Million bushels
# 1         1      Beginning stocks    Barley         Crops   Million bushels
# 2         2      Beginning stocks    Barley         Crops   Million bushels
# 3         3      Beginning stocks    Barley         Crops   Million bushels
# 4         4      Beginning stocks    Barley         Crops   Million bushels
# ...     ...                   ...       ...           ...               ...
# 2923   2923  Yield/harvested acre     Wheat         Crops  Bushels per acre
# 2924   2924  Yield/harvested acre     Wheat         Crops  Bushels per acre
# 2925   2925  Yield/harvested acre     Wheat         Crops  Bushels per acre
# 2926   2926  Yield/harvested acre     Wheat         Crops  Bushels per acre
# 2927   2927  Yield/harvested acre     Wheat         Crops  Bushels per acre
#
#          YearType     Year  Value
# 0     Market year  2017/18  106.0
# 1     Market year  2018/19   94.0
# 2     Market year  2019/20   88.0
# 3     Market year  2020/21   87.0
# 4     Market year  2021/22   83.0
# ...           ...      ...    ...
# 2923  Market year  2024/25   49.8
# 2924  Market year  2025/26   50.2
# 2925  Market year  2026/27   50.6
# 2926  Market year  2027/28   51.0
# 2927  Market year  2028/29   51.4
#
# [2928 rows x 8 columns]

# %% [markdown]
# ### Transpose Loaded Data into a new Data Frame

# %%
# create a new table
df_agriculture = pd.DataFrame(pd.read_csv('dataset/Projection2019.csv'))
df_units = pd.DataFrame(pd.read_csv('dataset/Projection2019.csv'))

# Get all attributes from the main table 
attributes = pd.DataFrame(columns = df_main['Attribute'].unique())

# Concatenate the columns to the new table
df_agriculture = pd.concat([df_agriculture, attributes], axis = 1)
df_units = pd.concat([df_units, attributes], axis = 1)

# Set new index and drop 'Attribute', 'Units' and 'Value' columns
drop_columns = ['Attribute', 'Value', 'Units']
df_agriculture.drop(columns = drop_columns, inplace = True)
df_units.drop(columns = drop_columns, inplace = True)

# Drop duplicates
df_agriculture.drop_duplicates(inplace = True)
df_units.drop_duplicates(inplace = True)

# Reset table index before iterating to fill in NaN values
df_agriculture.reset_index(drop = True, inplace = True)
df_units.reset_index(drop = True, inplace = True)

# Transpose df_main into df_agriculture and df_units
tranpose_table(df_main, df_agriculture, df_units)

# Save to CSV
df_agriculture.to_csv('dataset/transposed_agriculture.csv')
df_units.to_csv('dataset/transpose_units.csv')

# %% [markdown]
# ### Tranposed tables

# %%
# Agriculture table tranposed
df_agriculture
# Out:
#     Commodity CommodityType     YearType     Year Beginning stocks Domestic  \
# 0      Barley         Crops  Market year  2017/18            106.0    158.0
# 1      Barley         Crops  Market year  2018/19             94.0    170.0
# 2      Barley         Crops  Market year  2019/20             88.0    175.0
# 3      Barley         Crops  Market year  2020/21             87.0    180.0
# 4      Barley         Crops  Market year  2021/22             83.0    185.0
# ..        ...           ...          ...      ...              ...      ...
# 199     Wheat         Crops  Market year  2024/25            942.0   1180.0
# 200     Wheat         Crops  Market year  2025/26            959.0   1184.0
# 201     Wheat         Crops  Market year  2026/27            953.0   1188.0
# 202     Wheat         Crops  Market year  2027/28            960.0   1192.0
# 203     Wheat         Crops  Market year  2028/29            959.0   1196.0
#
#     Ending stocks Exports Farm price Feed & residual  ... Total demand  \
# 0            94.0     5.0       4.47             1.0  ...          NaN
# 1            88.0     5.0       4.65            15.0  ...          NaN
# 2            87.0     5.0       4.75            20.0  ...          NaN
# 3            83.0     5.0       4.75            25.0  ...          NaN
# 4            83.0     5.0        4.8            30.0  ...          NaN
# ..            ...     ...        ...             ...  ...          ...
# 199         959.0  1000.0        5.2           120.0  ...          NaN
# 200         953.0  1000.0        5.1           120.0  ...          NaN
# 201         960.0  1000.0        5.0           120.0  ...          NaN
# 202         959.0  1000.0        5.0           120.0  ...          NaN
# 203         945.0  1025.0        5.0           120.0  ...          NaN
#
#     Soybean oil, for methyl ester Crush Crush margin Seed & residual  \
# 0                             NaN   NaN          NaN             NaN
# 1                             NaN   NaN          NaN             NaN
# 2                             NaN   NaN          NaN             NaN
# 3                             NaN   NaN          NaN             NaN
# 4                             NaN   NaN          NaN             NaN
# ..                            ...   ...          ...             ...
# 199                           NaN   NaN          NaN             NaN
# 200                           NaN   NaN          NaN             NaN
# 201                           NaN   NaN          NaN             NaN
# 202                           NaN   NaN          NaN             NaN
# 203                           NaN   NaN          NaN             NaN
#
#     Hen turkeys, National Turkey, farm  \
# 0                     NaN          NaN
# 1                     NaN          NaN
# 2                     NaN          NaN
# 3                     NaN          NaN
# 4                     NaN          NaN
# ..                    ...          ...
# 199                   NaN          NaN
# 200                   NaN          NaN
# 201                   NaN          NaN
# 202                   NaN          NaN
# 203                   NaN          NaN
#
#     Variable cost of production (per pound)    Food  Seed
# 0                                       NaN     NaN   NaN
# 1                                       NaN     NaN   NaN
# 2                                       NaN     NaN   NaN
# 3                                       NaN     NaN   NaN
# 4                                       NaN     NaN   NaN
# ..                                      ...     ...   ...
# 199                                     NaN   995.0  65.0
# 200                                     NaN   999.0  65.0
# 201                                     NaN  1003.0  65.0
# 202                                     NaN  1007.0  65.0
# 203                                     NaN  1011.0  65.0
#
# [204 rows x 76 columns]

# %% [markdown]
# #### Tranposed Units table

# %%
# Units table tranposed
pd.set_option('display.max_columns', None)
df_units
# Out:
#     Commodity CommodityType     YearType     Year Beginning stocks  \
# 0      Barley         Crops  Market year  2017/18  Million bushels
# 1      Barley         Crops  Market year  2018/19  Million bushels
# 2      Barley         Crops  Market year  2019/20  Million bushels
# 3      Barley         Crops  Market year  2020/21  Million bushels
# 4      Barley         Crops  Market year  2021/22  Million bushels
# ..        ...           ...          ...      ...              ...
# 199     Wheat         Crops  Market year  2024/25  Million bushels
# 200     Wheat         Crops  Market year  2025/26  Million bushels
# 201     Wheat         Crops  Market year  2026/27  Million bushels
# 202     Wheat         Crops  Market year  2027/28  Million bushels
# 203     Wheat         Crops  Market year  2028/29  Million bushels
#
#             Domestic    Ending stocks          Exports          Farm price  \
# 0    Million bushels  Million bushels  Million bushels  Dollars per bushel
# 1    Million bushels  Million bushels  Million bushels  Dollars per bushel
# 2    Million bushels  Million bushels  Million bushels  Dollars per bushel
# 3    Million bushels  Million bushels  Million bushels  Dollars per bushel
# 4    Million bushels  Million bushels  Million bushels  Dollars per bushel
# ..               ...              ...              ...                 ...
# 199  Million bushels  Million bushels  Million bushels  Dollars per bushel
# 200  Million bushels  Million bushels  Million bushels  Dollars per bushel
# 201  Million bushels  Million bushels  Million bushels  Dollars per bushel
# 202  Million bushels  Million bushels  Million bushels  Dollars per bushel
# 203  Million bushels  Million bushels  Million bushels  Dollars per bushel
#
#      Feed & residual Food, seed, & industrial Harvested acres  \
# 0    Million bushels          Million bushels   Million acres
# 1    Million bushels          Million bushels   Million acres
# 2    Million bushels          Million bushels   Million acres
# 3    Million bushels          Million bushels   Million acres
# 4    Million bushels          Million bushels   Million acres
# ..               ...                      ...             ...
# 199  Million bushels                      NaN   Million acres
# 200  Million bushels                      NaN   Million acres
# 201  Million bushels                      NaN   Million acres
# 202  Million bushels                      NaN   Million acres
# 203  Million bushels                      NaN   Million acres
#
#              Imports           Loan rate  Planted acres       Production  \
# 0    Million bushels  Dollars per bushel  Million acres  Million bushels
# 1    Million bushels  Dollars per bushel  Million acres  Million bushels
# 2    Million bushels  Dollars per bushel  Million acres  Million bushels
# 3    Million bushels  Dollars per bushel  Million acres  Million bushels
# 4    Million bushels  Dollars per bushel  Million acres  Million bushels
# ..               ...                 ...            ...              ...
# 199  Million bushels  Dollars per bushel  Million acres  Million bushels
# 200  Million bushels  Dollars per bushel  Million acres  Million bushels
# 201  Million bushels  Dollars per bushel  Million acres  Million bushels
# 202  Million bushels  Dollars per bushel  Million acres  Million bushels
# 203  Million bushels  Dollars per bushel  Million acres  Million bushels
#
#     Returns over variable costs (net returns) Stocks/use ratio, percent  \
# 0                            Dollars per acre                   Percent
# 1                            Dollars per acre                   Percent
# 2                            Dollars per acre                   Percent
# 3                            Dollars per acre                   Percent
# 4                            Dollars per acre                   Percent
# ..                                        ...                       ...
# 199                          Dollars per acre                   Percent
# 200                          Dollars per acre                   Percent
# 201                          Dollars per acre                   Percent
# 202                          Dollars per acre                   Percent
# 203                          Dollars per acre                   Percent
#
#         Supply total Total use/disposition  \
# 0    Million bushels       Million bushels
# 1    Million bushels       Million bushels
# 2    Million bushels       Million bushels
# 3    Million bushels       Million bushels
# 4    Million bushels       Million bushels
# ..               ...                   ...
# 199  Million bushels       Million bushels
# 200  Million bushels       Million bushels
# 201  Million bushels       Million bushels
# 202  Million bushels       Million bushels
# 203  Million bushels       Million bushels
#
#     Variable cost of production (per acre)  \
# 0                                  Dollars
# 1                                  Dollars
# 2                                  Dollars
# 3                                  Dollars
# 4                                  Dollars
# ..                                     ...
# 199                                Dollars
# 200                                Dollars
# 201                                Dollars
# 202                                Dollars
# 203                                Dollars
#
#     Variable cost of production (per bushel) Yield/harvested acre  \
# 0                                    Dollars     Bushels per acre
# 1                                    Dollars     Bushels per acre
# 2                                    Dollars     Bushels per acre
# 3                                    Dollars     Bushels per acre
# 4                                    Dollars     Bushels per acre
# ..                                       ...                  ...
# 199                                  Dollars     Bushels per acre
# 200                                  Dollars     Bushels per acre
# 201                                  Dollars     Bushels per acre
# 202                                  Dollars     Bushels per acre
# 203                                  Dollars     Bushels per acre
#
#     Beef cattle, farm Beef cow inventory Calves, farm Cattle inventory  \
# 0                 NaN                NaN          NaN              NaN
# 1                 NaN                NaN          NaN              NaN
# 2                 NaN                NaN          NaN              NaN
# 3                 NaN                NaN          NaN              NaN
# 4                 NaN                NaN          NaN              NaN
# ..                ...                ...          ...              ...
# 199               NaN                NaN          NaN              NaN
# 200               NaN                NaN          NaN              NaN
# 201               NaN                NaN          NaN              NaN
# 202               NaN                NaN          NaN              NaN
# 203               NaN                NaN          NaN              NaN
#
#     Commercial production Feeder steers, Okla. City Production, farm  \
# 0                     NaN                       NaN              NaN
# 1                     NaN                       NaN              NaN
# 2                     NaN                       NaN              NaN
# 3                     NaN                       NaN              NaN
# 4                     NaN                       NaN              NaN
# ..                    ...                       ...              ...
# 199                   NaN                       NaN              NaN
# 200                   NaN                       NaN              NaN
# 201                   NaN                       NaN              NaN
# 202                   NaN                       NaN              NaN
# 203                   NaN                       NaN              NaN
#
#     Steers, 5-area, all grades Total cow inventory Total disappearance  \
# 0                          NaN                 NaN                 NaN
# 1                          NaN                 NaN                 NaN
# 2                          NaN                 NaN                 NaN
# 3                          NaN                 NaN                 NaN
# 4                          NaN                 NaN                 NaN
# ..                         ...                 ...                 ...
# 199                        NaN                 NaN                 NaN
# 200                        NaN                 NaN                 NaN
# 201                        NaN                 NaN                 NaN
# 202                        NaN                 NaN                 NaN
# 203                        NaN                 NaN                 NaN
#
#     Total production Broilers, farm Disappearance  \
# 0                NaN            NaN           NaN
# 1                NaN            NaN           NaN
# 2                NaN            NaN           NaN
# 3                NaN            NaN           NaN
# 4                NaN            NaN           NaN
# ..               ...            ...           ...
# 199              NaN            NaN           NaN
# 200              NaN            NaN           NaN
# 201              NaN            NaN           NaN
# 202              NaN            NaN           NaN
# 203              NaN            NaN           NaN
#
#     Federally inspected slaughter National composite price Ethanol for fuel  \
# 0                             NaN                      NaN              NaN
# 1                             NaN                      NaN              NaN
# 2                             NaN                      NaN              NaN
# 3                             NaN                      NaN              NaN
# 4                             NaN                      NaN              NaN
# ..                            ...                      ...              ...
# 199                           NaN                      NaN              NaN
# 200                           NaN                      NaN              NaN
# 201                           NaN                      NaN              NaN
# 202                           NaN                      NaN              NaN
# 203                           NaN                      NaN              NaN
#
#     Commercial use: Milkfat basis Commercial use: Skim solids Milk per cow  \
# 0                             NaN                         NaN          NaN
# 1                             NaN                         NaN          NaN
# 2                             NaN                         NaN          NaN
# 3                             NaN                         NaN          NaN
# 4                             NaN                         NaN          NaN
# ..                            ...                         ...          ...
# 199                           NaN                         NaN          NaN
# 200                           NaN                         NaN          NaN
# 201                           NaN                         NaN          NaN
# 202                           NaN                         NaN          NaN
# 203                           NaN                         NaN          NaN
#
#     Milk production Number of cows Prices: All milk Eggs, farm Hatching use  \
# 0               NaN            NaN              NaN        NaN          NaN
# 1               NaN            NaN              NaN        NaN          NaN
# 2               NaN            NaN              NaN        NaN          NaN
# 3               NaN            NaN              NaN        NaN          NaN
# 4               NaN            NaN              NaN        NaN          NaN
# ..              ...            ...              ...        ...          ...
# 199             NaN            NaN              NaN        NaN          NaN
# 200             NaN            NaN              NaN        NaN          NaN
# 201             NaN            NaN              NaN        NaN          NaN
# 202             NaN            NaN              NaN        NaN          NaN
# 203             NaN            NaN              NaN        NaN          NaN
#
#     New York, Grade A large Per capita Retail weight: Broilers  \
# 0                       NaN        NaN                     NaN
# 1                       NaN        NaN                     NaN
# 2                       NaN        NaN                     NaN
# 3                       NaN        NaN                     NaN
# 4                       NaN        NaN                     NaN
# ..                      ...        ...                     ...
# 199                     NaN        NaN                     NaN
# 200                     NaN        NaN                     NaN
# 201                     NaN        NaN                     NaN
# 202                     NaN        NaN                     NaN
# 203                     NaN        NaN                     NaN
#
#     Retail weight: Lamb & mutton Retail weight: Other chicken  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 199                          NaN                          NaN
# 200                          NaN                          NaN
# 201                          NaN                          NaN
# 202                          NaN                          NaN
# 203                          NaN                          NaN
#
#     Retail weight: Red meat & poultry Retail weight: Total beef  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# ..                                ...                       ...
# 199                               NaN                       NaN
# 200                               NaN                       NaN
# 201                               NaN                       NaN
# 202                               NaN                       NaN
# 203                               NaN                       NaN
#
#     Retail weight: Total pork Retail weight: Total poultry  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ..                        ...                          ...
# 199                       NaN                          NaN
# 200                       NaN                          NaN
# 201                       NaN                          NaN
# 202                       NaN                          NaN
# 203                       NaN                          NaN
#
#     Retail weight: Total red meat Retail weight: Total veal  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ..                            ...                       ...
# 199                           NaN                       NaN
# 200                           NaN                       NaN
# 201                           NaN                       NaN
# 202                           NaN                       NaN
# 203                           NaN                       NaN
#
#     Retail weight: Turkeys Hog, inventory Dec.1, previous year Hogs, farm  \
# 0                      NaN                                 NaN        NaN
# 1                      NaN                                 NaN        NaN
# 2                      NaN                                 NaN        NaN
# 3                      NaN                                 NaN        NaN
# 4                      NaN                                 NaN        NaN
# ..                     ...                                 ...        ...
# 199                    NaN                                 NaN        NaN
# 200                    NaN                                 NaN        NaN
# 201                    NaN                                 NaN        NaN
# 202                    NaN                                 NaN        NaN
# 203                    NaN                                 NaN        NaN
#
#     National base, live eqv Milling rate, percent  \
# 0                       NaN                   NaN
# 1                       NaN                   NaN
# 2                       NaN                   NaN
# 3                       NaN                   NaN
# 4                       NaN                   NaN
# ..                      ...                   ...
# 199                     NaN                   NaN
# 200                     NaN                   NaN
# 201                     NaN                   NaN
# 202                     NaN                   NaN
# 203                     NaN                   NaN
#
#     Variable cost of production (per cwt.) Crushing yields Prices  \
# 0                                      NaN             NaN    NaN
# 1                                      NaN             NaN    NaN
# 2                                      NaN             NaN    NaN
# 3                                      NaN             NaN    NaN
# 4                                      NaN             NaN    NaN
# ..                                     ...             ...    ...
# 199                                    NaN             NaN    NaN
# 200                                    NaN             NaN    NaN
# 201                                    NaN             NaN    NaN
# 202                                    NaN             NaN    NaN
# 203                                    NaN             NaN    NaN
#
#     Total demand Soybean oil, for methyl ester Crush Crush margin  \
# 0            NaN                           NaN   NaN          NaN
# 1            NaN                           NaN   NaN          NaN
# 2            NaN                           NaN   NaN          NaN
# 3            NaN                           NaN   NaN          NaN
# 4            NaN                           NaN   NaN          NaN
# ..           ...                           ...   ...          ...
# 199          NaN                           NaN   NaN          NaN
# 200          NaN                           NaN   NaN          NaN
# 201          NaN                           NaN   NaN          NaN
# 202          NaN                           NaN   NaN          NaN
# 203          NaN                           NaN   NaN          NaN
#
#     Seed & residual Hen turkeys, National Turkey, farm  \
# 0               NaN                   NaN          NaN
# 1               NaN                   NaN          NaN
# 2               NaN                   NaN          NaN
# 3               NaN                   NaN          NaN
# 4               NaN                   NaN          NaN
# ..              ...                   ...          ...
# 199             NaN                   NaN          NaN
# 200             NaN                   NaN          NaN
# 201             NaN                   NaN          NaN
# 202             NaN                   NaN          NaN
# 203             NaN                   NaN          NaN
#
#     Variable cost of production (per pound)             Food             Seed
# 0                                       NaN              NaN              NaN
# 1                                       NaN              NaN              NaN
# 2                                       NaN              NaN              NaN
# 3                                       NaN              NaN              NaN
# 4                                       NaN              NaN              NaN
# ..                                      ...              ...              ...
# 199                                     NaN  Million bushels  Million bushels
# 200                                     NaN  Million bushels  Million bushels
# 201                                     NaN  Million bushels  Million bushels
# 202                                     NaN  Million bushels  Million bushels
# 203                                     NaN  Million bushels  Million bushels
#
# [204 rows x 76 columns]
